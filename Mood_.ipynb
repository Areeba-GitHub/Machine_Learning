# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('Mood_Tracker.xlsx')
print(df)
# Out:
#         Date      Mood  Score
# 0 2025-07-21     Happy      9
# 1 2025-07-22  Annxious      4
# 2 2025-07-23      Calm      7
# 3 2025-07-24   Excited     10
# 4 2025-07-25       Sad      3

# %%
df["Label"] = df["Mood"]

# Now plot with x and y both
plt.bar(df["Label"], df["Score"], color="lightpink", edgecolor="pink")
# Out:
# <BarContainer object of 5 artists>
